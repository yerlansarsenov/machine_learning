# %%
def solution(n):
    n = bin(n)[2:]
    #print(n)
    l = len(n)
    poses = []
    for i in range(l):
        if(n[i] == '1'):
            poses.append(i)
    #print(poses)
    if(len(poses) == 0):
        return 0
    maxx = 0
    for i in range(1,len(poses)):
        maxx = max(maxx, int(poses[i])-int(poses[i-1])-1)
    return maxx
        
solution(1041)
# Out:
# 5

# %%
solution(32)
# Out:
# 0

# %%
solution(529)
# Out:
# 4

# %%
solution(9)
# Out:
# 2

# %%
solution(15)
# Out:
# 0

# %%
solution(20)
# Out:
# 1

# %%
solution(2147483647)
# Out:
# 0
